# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('realest.csv')

# %%
data
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1     55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2     56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3     58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4     64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
# ..     ...      ...     ...   ...   ...     ...       ...     ...        ...
# 152   44.0      3.0   820.0   5.0  27.0     NaN       1.0     0.0        1.0
# 153   43.0      2.0   593.0   4.0  30.0   465.0       2.0     1.0        0.0
# 154   53.0      3.0   716.0   6.0  30.0   585.0       1.0     2.0        1.0
# 155   62.0      4.0   951.0   7.0  30.0   895.0       2.0     1.0        0.0
# 156    NaN      NaN     NaN   NaN   NaN     NaN       NaN     NaN        NaN
#
# [157 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      156 non-null    float64
#  1   Bedroom    156 non-null    float64
#  2   Space      146 non-null    float64
#  3   Room       156 non-null    float64
#  4   Lot        146 non-null    float64
#  5   Tax        147 non-null    float64
#  6   Bathroom   156 non-null    float64
#  7   Garage     156 non-null    float64
#  8   Condition  156 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
data = data.dropna(subset=['Tax'])
data = data.dropna(subset=['Space'])
data = data.dropna(subset=['Lot'])

# %%
data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Bedroom'}>,
#         <Axes: title={'center': 'Space'}>],
#        [<Axes: title={'center': 'Room'}>,
#         <Axes: title={'center': 'Lot'}>, <Axes: title={'center': 'Tax'}>],
#        [<Axes: title={'center': 'Bathroom'}>,
#         <Axes: title={'center': 'Garage'}>,
#         <Axes: title={'center': 'Condition'}>]], dtype=object)

# %%
data
# Out:
#      Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0     53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1     55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2     56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3     58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4     64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0
# ..     ...      ...     ...   ...   ...     ...       ...     ...        ...
# 149   32.0      4.0  1065.0   7.0  25.0   492.0       1.5     0.0        0.0
# 151   42.0      3.0   585.0   5.0  50.0   713.0       1.0     0.0        0.0
# 153   43.0      2.0   593.0   4.0  30.0   465.0       2.0     1.0        0.0
# 154   53.0      3.0   716.0   6.0  30.0   585.0       1.0     2.0        1.0
# 155   62.0      4.0   951.0   7.0  30.0   895.0       2.0     1.0        0.0
#
# [128 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['Price'], axis=1)
y = data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#      Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition  Price
# 97       4.0  1087.0   7.0  25.0   584.0       1.5     0.0        0.0   34.0
# 5        4.0   897.0   7.0  25.0   960.0       2.0     1.0        0.0   44.0
# 132      2.0   828.0   5.0  35.0   913.0       1.5     1.0        0.0   60.0
# 146      2.0  1114.0   7.0  30.0   746.0       2.0     0.0        1.0   64.0
# 107      3.0  1022.0   6.0  24.0   980.0       1.5     2.0        0.0   64.0
# ..       ...     ...   ...   ...     ...       ...     ...        ...    ...
# 114      8.0  2293.0  12.0  50.0  1181.0       3.0     2.0        0.0   90.0
# 15       2.0   782.0   5.0  25.0   834.0       1.0     0.0        0.0   60.0
# 43       4.0  1250.0   8.0  37.0   554.0       2.0     2.0        0.0   65.0
# 106      2.0   942.0   5.0  35.0   880.0       1.5     1.0        0.0   58.0
# 54       2.0   839.0   5.0  35.0   926.0       1.5     1.0        0.0   59.0
#
# [102 rows x 9 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'Bedroom'}>,
#         <Axes: title={'center': 'Space'}>,
#         <Axes: title={'center': 'Room'}>],
#        [<Axes: title={'center': 'Lot'}>, <Axes: title={'center': 'Tax'}>,
#         <Axes: title={'center': 'Bathroom'}>],
#        [<Axes: title={'center': 'Garage'}>,
#         <Axes: title={'center': 'Condition'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
train_data['Space'] = np.log(train_data['Space'] + 1)

# %%
train_data = train_data.drop(['Tax'], axis=1)

# %%
train_data
# Out:
#      Bedroom     Space  Room   Lot  Bathroom  Garage  Condition  Price
# 97       4.0  6.992096   7.0  25.0       1.5     0.0        0.0   34.0
# 5        4.0  6.800170   7.0  25.0       2.0     1.0        0.0   44.0
# 132      2.0  6.720220   5.0  35.0       1.5     1.0        0.0   60.0
# 146      2.0  7.016610   7.0  30.0       2.0     0.0        1.0   64.0
# 107      3.0  6.930495   6.0  24.0       1.5     2.0        0.0   64.0
# ..       ...       ...   ...   ...       ...     ...        ...    ...
# 114      8.0  7.738052  12.0  50.0       3.0     2.0        0.0   90.0
# 15       2.0  6.663133   5.0  25.0       1.0     0.0        0.0   60.0
# 43       4.0  7.131699   8.0  37.0       2.0     2.0        0.0   65.0
# 106      2.0  6.849066   5.0  35.0       1.5     1.0        0.0   58.0
# 54       2.0  6.733402   5.0  35.0       1.5     1.0        0.0   59.0
#
# [102 rows x 8 columns]

# %%
train_data['bedroom_ratio'] = train_data['Bedroom'] / train_data['Room']
train_data['bathroom_ratio'] = train_data['Bathroom'] / train_data['Room']
train_data['garage_ratio'] = train_data['Garage'] / train_data['Room']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train, y_train = train_data.drop(['Price'], axis=1), train_data['Price']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['Space'] = np.log(test_data['Space'] + 1)

test_data = test_data.drop(['Tax'], axis=1)

test_data['bedroom_ratio'] = test_data['Bedroom'] / test_data['Room']
test_data['bathroom_ratio'] = test_data['Bathroom'] / test_data['Room']
test_data['garage_ratio'] = test_data['Garage'] / test_data['Room']

# %%
X_test, y_test = test_data.drop(['Price'], axis=1), test_data['Price']

# %%
X_test_s = scaler.fit_transform(X_test)

# %%
test_data
# Out:
#      Bedroom     Space  Room   Lot  Bathroom  Garage  Condition  Price  \
# 57       4.0  6.781058   7.0  25.0       2.0     1.0        0.0   44.0
# 116      3.0  6.818924   6.0  25.0       1.0     0.0        0.0   44.0
# 86       4.0  7.153834   8.0  33.0       1.5     1.5        0.0   73.0
# 135      4.0  6.756932   7.0  25.0       2.0     1.0        0.0   41.0
# 37       3.0  6.369901   5.0  25.0       1.0     0.0        0.0   45.0
# 38       3.0  6.774224   6.0  25.0       1.0     0.0        0.0   47.0
# 105      1.0  6.593045   5.0  33.0       1.0     2.0        1.0   61.0
# 153      2.0  6.386879   4.0  30.0       2.0     1.0        0.0   43.0
# 65       5.0  6.929517   7.0  30.0       1.5     0.0        0.0   52.0
# 100      2.0  6.753438   5.0  27.0       1.0     0.0        1.0   46.0
# 133      3.0  6.920672   6.0  24.0       1.5     2.0        0.0   55.0
# 64       4.0  6.829794   6.0  25.0       1.0     0.0        0.0   47.0
# ...

# %%
train_data
# Out:
#      Bedroom     Space  Room   Lot  Bathroom  Garage  Condition  Price  \
# 97       4.0  6.992096   7.0  25.0       1.5     0.0        0.0   34.0
# 5        4.0  6.800170   7.0  25.0       2.0     1.0        0.0   44.0
# 132      2.0  6.720220   5.0  35.0       1.5     1.0        0.0   60.0
# 146      2.0  7.016610   7.0  30.0       2.0     0.0        1.0   64.0
# 107      3.0  6.930495   6.0  24.0       1.5     2.0        0.0   64.0
# ..       ...       ...   ...   ...       ...     ...        ...    ...
# 114      8.0  7.738052  12.0  50.0       3.0     2.0        0.0   90.0
# 15       2.0  6.663133   5.0  25.0       1.0     0.0        0.0   60.0
# 43       4.0  7.131699   8.0  37.0       2.0     2.0        0.0   65.0
# 106      2.0  6.849066   5.0  35.0       1.5     1.0        0.0   58.0
# 54       2.0  6.733402   5.0  35.0       1.5     1.0        0.0   59.0
#
#      bedroom_ratio  bathroom_ratio  garage_ratio
# 97        0.571429        0.214286      0.000000
# ...

# %%
X_test
# Out:
#      Bedroom     Space  Room   Lot  Bathroom  Garage  Condition  \
# 57       4.0  6.781058   7.0  25.0       2.0     1.0        0.0
# 116      3.0  6.818924   6.0  25.0       1.0     0.0        0.0
# 86       4.0  7.153834   8.0  33.0       1.5     1.5        0.0
# 135      4.0  6.756932   7.0  25.0       2.0     1.0        0.0
# 37       3.0  6.369901   5.0  25.0       1.0     0.0        0.0
# 38       3.0  6.774224   6.0  25.0       1.0     0.0        0.0
# 105      1.0  6.593045   5.0  33.0       1.0     2.0        1.0
# 153      2.0  6.386879   4.0  30.0       2.0     1.0        0.0
# 65       5.0  6.929517   7.0  30.0       1.5     0.0        0.0
# 100      2.0  6.753438   5.0  27.0       1.0     0.0        1.0
# 133      3.0  6.920672   6.0  24.0       1.5     2.0        0.0
# 64       4.0  6.829794   6.0  25.0       1.0     0.0        0.0
# 47       2.0  6.291569   5.0  50.0       1.0     0.0        0.0
# 88       8.0  7.709308  12.0  50.0       3.0     2.0        0.0
# ...

# %%
reg.score(X_test, y_test)
# Out:
# 0.6871561058955462

# %%
X_train
# Out:
#      Bedroom     Space  Room   Lot  Bathroom  Garage  Condition  \
# 97       4.0  6.992096   7.0  25.0       1.5     0.0        0.0
# 5        4.0  6.800170   7.0  25.0       2.0     1.0        0.0
# 132      2.0  6.720220   5.0  35.0       1.5     1.0        0.0
# 146      2.0  7.016610   7.0  30.0       2.0     0.0        1.0
# 107      3.0  6.930495   6.0  24.0       1.5     2.0        0.0
# ..       ...       ...   ...   ...       ...     ...        ...
# 114      8.0  7.738052  12.0  50.0       3.0     2.0        0.0
# 15       2.0  6.663133   5.0  25.0       1.0     0.0        0.0
# 43       4.0  7.131699   8.0  37.0       2.0     2.0        0.0
# 106      2.0  6.849066   5.0  35.0       1.5     1.0        0.0
# 54       2.0  6.733402   5.0  35.0       1.5     1.0        0.0
#
#      bedroom_ratio  bathroom_ratio  garage_ratio
# 97        0.571429        0.214286      0.000000
# 5         0.571429        0.285714      0.142857
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.9111325731006727

# %%
forest.estimator_
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

for i in range(5):
    print(f"Pohon ke-{i + 1}")
    estimator = forest.estimators_[i]

    plt.figure(figsize=(20, 10))
    plot_tree(estimator,
              feature_names=X_train.columns,
              filled=True,
              rounded=True,
              max_depth=3)  # boleh disesuaikan
    plt.title(f"Visualisasi Pohon ke-{i + 1}")
    plt.show()
# Out:
# Pohon ke-1
# Pohon ke-2
# Pohon ke-3
# Pohon ke-4
# Pohon ke-5
